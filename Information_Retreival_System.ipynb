# %%
# !pip install wikipedia
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11695 sha256=3f98bed64a5ed81d46822a78e57b039cc8247fbf825400ee13bb0b16e0ae35e3
#   Stored in directory: /root/.cache/pip/wheels/15/93/6d/5b2c68b8a64c7a7a04947b4ed6d89fb557dcc6bc27d1d7f3ba
# Successfully built wikipedia
# ...

# %%
import wikipedia
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import pandas as pd

# %%
def system():
  a="ab"
  articles=[]
  while (a!="q"):
    inp=input("Enter Article to be downloaded >")
    articles.append(inp)
    a=input("Press q to quit or any other key to continue >")
  query=input("Enter the query to be searched against >")
  wiki_lst=[]
  title=[]
  for article in articles:
    wiki_lst.append(wikipedia.page(article).content)
  tfidf=TfidfVectorizer()
  train_tfidf = tfidf.fit_transform(wiki_lst) 
  query_vec = tfidf.transform([query])
  sim1=cosine_similarity(train_tfidf,query_vec)
  data={"Article":wiki_lst,"Similarity Score":sim1.flatten()}
  df=pd.DataFrame(data)
  df.sort_values(["Similarity Score"],ascending=False, inplace=True)
  len=int(input("Enter the number of relevant results to be displayed"))
  sc=input("Do you want the esimilarity score as well ? [y/n] ")
  if sc=="y":
    print(display(df.head(len).style.hide_index()))
  else:
    for i in len(range(len)):
      print(f"ARTICLE {i+1}:\n")
      print(df[i])
      print("\n")

# %%
system()
# Out:
# Enter Article to be downloaded >Data Science
# Press q to quit or any other key to continue >w
# Enter Article to be downloaded >Artificial Intelligence
# Press q to quit or any other key to continue >w
# Enter Article to be downloaded >Natural Language Processing
# Press q to quit or any other key to continue >q
# Enter the query to be searched against >Data Science is trending
# Enter the number of relevant results to be displayed2
# Do you want the esimilarity score as well ? [y/n] y
# <style type="text/css">
# </style>
# <table id="T_d037b_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Article</th>
#       <th class="col_heading level0 col1" >Similarity Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...
